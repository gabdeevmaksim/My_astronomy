# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir('e:/Observations/BTA/s091021/MTDra/')

# %%
velos = pd.read_fwf('veloses_4861.32_iter_3.dat', widths=[13,13,13,13], header=None,names=['Phase','Narrow','Free','Broad'])

# %%
fig = plt.figure(figsize=[6,6])
ax = plt.subplot()
ax.plot(velos.Phase,velos.Narrow,c='red')
ax.plot(velos.Phase,velos.Free,c='green')
ax.plot(velos.Phase,velos.Broad,c='blue')

# %%
param=pd.read_fwf('parameters_4861.32_iter_3.dat',infer_nrows=11,header=None)

# %%
plt.plot(param[0],param[2])
