# %%
import matplotlib.pyplot as plot
import numpy as np
import pandas as pd
import os

# %%
os.chdir('e:\Observations\RTT150\T20201004\\')

# %%
file='aper_phot.csv'

# %%
phot=pd.read_csv(file)

# %%
chek = phot.Chk2
f = plot.figure()
plot.scatter(phot.iloc[:,0],phot.Obj1)
plot.scatter(phot.iloc[:,0],chek)
plot.ylim(23.5,19.5)
plot.title('Check star medianMag+/-std =' + str(np.median(chek)) + '+/-' + str(np.std(chek)))
plot.show()

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %%
f.savefig("XMMJ1832_aper.pdf", bbox_inches='tight')
