# %%
from astropy.io import fits
import os

os.chdir('e:\\Observations\\KECK1\\toGeorgiy\\')

# %%
test = fits.open('r220126_00054.fits')
test.info()
# Out:
# Filename: r220126_00054.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     336   (2208, 4188)   int16 (rescales to uint16)
#   1  Exposure Events    1 TableHDU        17   3R x 2C   [A26, A80]

# %%
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
image_data = fits.getdata('r220126_00055.fits', ext = 0)
plt.style.use(astropy_mpl_style)
plt.figure()
plt.imshow(image_data.T, cmap='gray', vmin = 100, vmax = 1000)
#plt.colorbar()

# %%
num = '43'
img = fits.getdata('r220126_00'+num+'.fits', ext=0)
hdu = fits.PrimaryHDU(img.T)
hdul = fits.HDUList([hdu])
hdul.writeto('obj_00'+num+'.fits', overwrite=True)
