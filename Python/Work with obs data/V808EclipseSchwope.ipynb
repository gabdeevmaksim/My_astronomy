# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
Ph09 = pd.read_csv('E:\Observations\ZTE\\2018-L\Ph-09nov.dat', sep='\s+', header=None, engine='python')
Ph10 = pd.read_csv('E:\Observations\ZTE\\2018-L\Ph-10nov.dat', sep='\s+', header=None, engine='python')
Ph11 = pd.read_csv('E:\Observations\ZTE\\2018-L\Ph-11nov.dat', sep='\s+', header=None, engine='python')
Ph14 = pd.read_csv('E:\Observations\ZTE\\2018-L\Ph-14nov.dat', sep='\s+', header=None, engine='python')

# %%
plot.scatter(Ph09.iloc[0:][2],Ph09.iloc[0:][1])
plot.xlim(8432.342,8432.348)
# Out:
# (8432.342, 8432.348)

# %%
plot.scatter(Ph09.iloc[0:][2],Ph09.iloc[0:][1])
plot.xlim(8432.275,8432.282)
# Out:
# (8432.275, 8432.282)

# %%
plot.scatter(Ph10.iloc[0:][2],Ph10.iloc[0:][1])
plot.xlim(8433.278,8433.285)
# Out:
# (8433.278, 8433.285)

# %%
plot.scatter(Ph11.iloc[0:][2],Ph11.iloc[0:][1])
plot.xlim(8434.28,8434.288)
# Out:
# (8434.28, 8434.288)

# %%
plot.scatter(Ph11.iloc[0:][2],Ph11.iloc[0:][1])
plot.xlim(8434.348,8434.355)
# Out:
# (8434.348, 8434.355)

# %%
plot.scatter(Ph14.iloc[0:][2],Ph14.iloc[0:][1])
plot.xlim(8437.223,8437.23)
# Out:
# (8437.223, 8437.23)

# %%
plot.scatter(Ph14.iloc[0:][2],Ph14.iloc[0:][1])
plot.xlim(8437.290,8437.297)
# Out:
# (8437.29, 8437.297)

# %%
plot.scatter(Ph14.iloc[0:][2],Ph14.iloc[0:][1])
plot.xlim(8437.357,8437.364)
# Out:
# (8437.357, 8437.364)

# %%
Ph09 = Ph09.sort_values(by=2)
Ph14 = Ph14.sort_values(by=2)

# %%
(Ph14.iloc[3][2]-Ph14.iloc[2][2])*86400
# Out:
# 62.20800000010058
