# %%
import pandas as pd
import matplotlib.pyplot as plt
import os 

os.chdir('e:/Observations/BTA/s091021/MTDra_phot/')

# %%
lc = pd.read_csv('phot.txt')

# %%
ph = pd.read_csv('phase_all.dat', header=None)
JD = pd.read_csv('JD.dat', header=None)

# %%
plt.errorbar(JD[0],lc.cv,lc['cv_err'], fmt='.b')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(JD[0],lc.cv,lc['cv_err'], fmt='.b')
#plt.ylim(18.6,17.6)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(ph[0],lc.cv,lc['cv_err'], fmt='.b')
plt.ylim(17.5,16.9)
# Out:
# (17.5, 16.9)
